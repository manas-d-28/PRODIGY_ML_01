# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
train = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/train.csv")
test = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/test.csv")

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train['FullBathTotal'] =  train['BsmtFullBath'] + train['FullBath']
train['HalfBathTotal'] = train['BsmtHalfBath'] + train['HalfBath']

# %%
train2 = pd.DataFrame(train, columns=['LotArea', 'HalfBathTotal' , 'FullBathTotal' , 'BedroomAbvGr'])
y = train['SalePrice']

# %%
train2.columns
# Out:
# Index(['LotArea', 'HalfBathTotal', 'FullBathTotal', 'BedroomAbvGr'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

# fir the scalar to train set, it will learn the parameteres
scalar.fit(train2)

# Transform train and test sets
train2S = scalar.transform(train2)

# %%
train2S
# Out:
# array([[-0.20714171,  1.01040607,  1.37960564,  0.16377912],
#        [-0.09188637,  1.01040607,  0.01310345,  0.16377912],
#        [ 0.07347998,  1.01040607,  1.37960564,  0.16377912],
#        ...,
#        [-0.14781027, -0.79521555,  0.01310345,  1.39002276],
#        [-0.08016039, -0.79521555,  0.01310345, -1.06246453],
#        [-0.05811155,  1.01040607,  0.01310345,  0.16377912]])

# %%
train2S= pd.DataFrame(train2S, columns = train2.columns)

# %%
train2S.isnull().sum()
# Out:
# LotArea          0
# HalfBathTotal    0
# FullBathTotal    0
# BedroomAbvGr     0
# dtype: int64

# %%
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
# '''''X_train, X_test,y_train, y_test = train_test_split(train2,y , 
#                                    random_state=42,  
#                                    test_size=0.2)''''''

# %%
#X_train.head()

# %%
model.fit(train2S , y)
# Out:
# LinearRegression()

# %%
#final = model.predict(X_test)

# %%
#from sklearn.metrics import mean_squared_error as mse

#rmse = (mse(final , y_test))**(1/2)
#print(rmse)

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
FullBathTotal2 = test['BsmtFullBath'] + test['FullBath']
HalfBathTotal2 = test['BsmtHalfBath'] + test['HalfBath']


test['FullBathTotal'] = FullBathTotal2
test['HalfBathTotal'] = HalfBathTotal2

# %%
test2 = pd.DataFrame(test, columns=['LotArea', 'HalfBathTotal' , 'FullBathTotal' , 'BedroomAbvGr'])
test2.isnull().sum()
# Out:
# LotArea          0
# HalfBathTotal    2
# FullBathTotal    2
# BedroomAbvGr     0
# dtype: int64

# %%
test2["HalfBathTotal"].fillna(0, inplace = True)
# Out:
# /tmp/ipykernel_33/1535915263.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test2["HalfBathTotal"].fillna(0, inplace = True)

# %%
test2["FullBathTotal"].fillna(0,inplace = True)
# Out:
# /tmp/ipykernel_33/1457636606.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test2["FullBathTotal"].fillna(0,inplace = True)

# %%
test2.isnull().sum()
# Out:
# LotArea          0
# HalfBathTotal    0
# FullBathTotal    0
# BedroomAbvGr     0
# dtype: int64

# %%
scalar2 = StandardScaler()

# fir the scalar to train set, it will learn the parameteres
scalar2.fit(test2)

# Transform train and test sets
test2S = scalar2.transform(test2)

# %%
test2.head()
# Out:
#    LotArea  HalfBathTotal  FullBathTotal  BedroomAbvGr
# 0    11622            0.0            1.0             2
# 1    14267            1.0            1.0             3
# 2    13830            1.0            2.0             3
# 3     9978            1.0            2.0             3
# 4     5005            0.0            2.0             2

# %%
# test2S.isnull().sum()

# %%
test2S= pd.DataFrame(test2S, columns = test2.columns)

# %%
prdicted = model.predict(test2S)

# %%
prdicted
# Out:
# array([112816.69343812, 154545.96471336, 209601.91828426, ...,
#        188928.25812347, 145882.86336453, 200085.18671888])

# %%
test3 = pd.DataFrame(test, columns=['Id','LotArea', 'HalfBathTotal' , 'FullBathTotal' , 'BedroomAbvGr'])

# %%
test3.isnull().sum()
# Out:
# Id               0
# LotArea          0
# HalfBathTotal    2
# FullBathTotal    2
# BedroomAbvGr     0
# dtype: int64

# %%
output = pd.DataFrame({'ID': test3.Id,'SalePrice': prdicted})

# %%
output.head()
# Out:
#      ID      SalePrice
# 0  1461  112816.693438
# 1  1462  154545.964713
# 2  1463  209601.918284
# 3  1464  200879.945886
# 4  1465  153879.451417

# %%
output.to_csv('submission.csv' , index=False)

# %%
submitted = pd.read_csv('/kaggle/working/submission.csv')

# %%
submitted.head()
# Out:
#      ID      SalePrice
# 0  1461  112816.693438
# 1  1462  154545.964713
# 2  1463  209601.918284
# 3  1464  200879.945886
# 4  1465  153879.451417
